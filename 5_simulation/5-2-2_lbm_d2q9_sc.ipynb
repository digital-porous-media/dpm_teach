# %% [markdown]
# # 2D Multiphase Lattice Boltzmann (LBM) Simulations
#
# __Author(s):__ Bernard Chang and Masa Prodanovic
#
# __Last Update:__ Sep. 2025
#
# Copyright © 2025 Digital Porous Media Team. All rights reserved.
#
# ---
